# %% [markdown]
# ### Dataset for "Understanding the AC conductivity and permittivity of trapdoor chabazites for future development of next-generation gas sensors" - https://researchdata.bath.ac.uk/402/

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data_dir = 'C:\\Users\\Ishani\\Downloads\\Open_Access_Dataset\\Open Access Dataset'

# %%
#df = pd.read_csv(data_dir +'\\AC Cond heating data.xlsx')
df = pd.read_excel(r'C:\Users\Ishani\Downloads\Open_Access_Dataset\Open Access Dataset\AC Cond heating data.xlsx')

# %%
df.head()
# Out:
#    Frequency / Hz  Conductivity 30oC / Sm^-1  Cond. 110 oC / Sm^-1  \
# 0       1000000.0                   0.000343              0.000339
# 1        837677.7                   0.000290              0.000286
# 2        701703.8                   0.000249              0.000246
# 3        587801.6                   0.000217              0.000215
# 4        492388.3                   0.000192              0.000190
#
#    Cond. 210 oC / Sm^-1  Cond. 310 oC / Sm^-1  Cond. 410 oC / Sm^-1  \
# 0              0.000279              0.000109              0.000201
# 1              0.000228              0.000084              0.000169
# 2              0.000188              0.000066              0.000144
# 3              0.000158              0.000053              0.000125
# 4              0.000134              0.000044              0.000111
#
#    Cond. 510 oC / Sm^-1  Cond. 610 oC / Sm^-1  Cond. 710 oC / Sm^-1
# 0              0.000536              0.001459              0.003004
# ...

# %%
df.columns
# Out:
# Index(['Frequency / Hz', 'Conductivity 30oC / Sm^-1', 'Cond. 110 oC / Sm^-1',
#        'Cond. 210 oC / Sm^-1', 'Cond. 310 oC / Sm^-1', 'Cond. 410 oC / Sm^-1',
#        'Cond. 510 oC / Sm^-1', 'Cond. 610 oC / Sm^-1', 'Cond. 710 oC / Sm^-1'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Frequency / Hz             92 non-null     float64
#  1   Conductivity 30oC / Sm^-1  92 non-null     float64
#  2   Cond. 110 oC / Sm^-1       92 non-null     float64
#  3   Cond. 210 oC / Sm^-1       92 non-null     float64
#  4   Cond. 310 oC / Sm^-1       92 non-null     float64
#  5   Cond. 410 oC / Sm^-1       92 non-null     float64
#  6   Cond. 510 oC / Sm^-1       92 non-null     float64
#  7   Cond. 610 oC / Sm^-1       92 non-null     float64
#  8   Cond. 710 oC / Sm^-1       92 non-null     float64
# dtypes: float64(9)
# memory usage: 6.6 KB

# %%
df['Frequency / Hz'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     1000000.000000
# 1      837677.700000
# 2      701703.800000
# 3      587801.600000
# 4      492388.300000
#            ...
# 87          0.203092
# 88          0.170125
# 89          0.142510
# 90          0.119378
# 91          0.100000
# Name: Frequency / Hz, Length: 92, dtype: float64>

# %%
df.describe()
# Out:
#        Frequency / Hz  Conductivity 30oC / Sm^-1  Cond. 110 oC / Sm^-1  \
# count       92.000000                  92.000000             92.000000
# mean     66962.829020                   0.000062              0.000058
# std     179738.609558                   0.000058              0.000058
# min          0.100000                   0.000011              0.000011
# 25%          5.639482                   0.000036              0.000031
# 50%        317.468650                   0.000044              0.000038
# 75%      17836.700000                   0.000059              0.000055
# max    1000000.000000                   0.000343              0.000339
#
#        Cond. 210 oC / Sm^-1  Cond. 310 oC / Sm^-1  Cond. 410 oC / Sm^-1  \
# count             92.000000             92.000000             92.000000
# mean               0.000035              0.000010              0.000035
# std                0.000046              0.000017              0.000034
# ...

# %%
df.isna().sum()
# Out:
# Frequency / Hz               0
# Conductivity 30oC / Sm^-1    0
# Cond. 110 oC / Sm^-1         0
# Cond. 210 oC / Sm^-1         0
# Cond. 310 oC / Sm^-1         0
# Cond. 410 oC / Sm^-1         0
# Cond. 510 oC / Sm^-1         0
# Cond. 610 oC / Sm^-1         0
# Cond. 710 oC / Sm^-1         0
# dtype: int64

# %%
df['Conductivity 30oC / Sm^-1'].max()
# Out:
# 0.000342748843734967

# %%
df.max()
# Out:
# Frequency / Hz               1000000.000000
# Conductivity 30oC / Sm^-1          0.000343
# Cond. 110 oC / Sm^-1               0.000339
# Cond. 210 oC / Sm^-1               0.000279
# Cond. 310 oC / Sm^-1               0.000109
# Cond. 410 oC / Sm^-1               0.000201
# Cond. 510 oC / Sm^-1               0.000536
# Cond. 610 oC / Sm^-1               0.001459
# Cond. 710 oC / Sm^-1               0.003004
# dtype: float64

# %% [markdown]
# # Visualizing Data

# %%
sns.heatmap(df.corr())

# %%
sns.scatterplot(df['Frequency / Hz'],df['Conductivity 30oC / Sm^-1'])

# %%
sns.scatterplot(df['Frequency / Hz'],df['Cond. 710 oC / Sm^-1'],edgecolor=None)

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Cond. 710 oC / Sm^-1'])

# %%
sns.distplot(df['Cond. 710 oC / Sm^-1'],kde=False,bins=3,color='red')

# %%
sns.jointplot(df['Cond. 510 oC / Sm^-1'],df['Cond. 710 oC / Sm^-1'])
